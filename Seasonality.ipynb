# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Processed_data.csv", index_col=1, parse_dates=True)

# %%
from statsmodels.tsa.seasonal import STL

# %%
day = STL(data["Total Load Interpolated"], period=96, seasonal=97*7, seasonal_jump=97*7, trend_jump=len(data)).fit()

# %%
plt.plot(day.seasonal[:96*31])

# %%
month = STL(day.resid, period=96*31, seasonal=97*7*3, seasonal_jump=96*31*4+1, trend_jump=len(data)).fit()

# %%
plt.plot(month.seasonal[:96*31*4])

# %%
year = STL(signal_month, period=96, seasonal_deg=0, seasonal=97, trend_jump=len(X)).fit()

# %%
plt.plot(month.seasonal[:1000])
plt.plot(month.trend[:1000])

# %%
signal_day = month.resid

# %%
day = STL(signal_day, period=96, seasonal_deg=0, seasonal=97, trend_jump=len(X)).fit()

# %%
series = STL(data["Total Load Interpolated"], period=96, seasonal_deg=0, seasonal=97, trend_jump=len(X)).fit()
print(-1, (np.mean(series.resid**2))**0.5)
for i in range(10):
    series = STL(series.resid, period=96, seasonal_deg=0, seasonal=97, trend_jump=len(X)).fit()
    print(i, (np.mean(series.resid**2))**0.5)
# Out:
# -1 1477.136664967351
# 0 1476.7833062589275
# 1 1477.0737587585502
# 2 1477.298377053622
# 3 1477.4741437422622
# 4 1477.6327045002117
# 5 1477.7990865906766
# 6 1477.9938393503558
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 4
#       2 print(-1, (np.mean(series.resid**2))**0.5)
#       3 for i in range(10):
# ----> 4     series = STL(series.resid, period=96, seasonal_deg=0, seasonal=97, trend_jump=len(X)).fit()
#       5     print(i, (np.mean(series.resid**2))**0.5)
#
# File statsmodels/tsa/stl/_stl.pyx:357, in statsmodels.tsa.stl._stl.STL.fit()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:371, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     366 _mgr: SingleManager
#     368 # ----------------------------------------------------------------------
# ...

# %% [markdown]
# - Predict the seasonal info as well as rests and trend
