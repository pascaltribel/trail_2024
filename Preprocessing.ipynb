# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import scipy
from datetime import datetime

# %%
filepath = "Data/Belgium/ELIA/ods001.csv"

# %%
data = pd.read_csv(filepath, delimiter=";")[749:][::-1].reset_index().drop("index", axis=1)

# %%
data["Datetime"] = pd.to_datetime(data["Datetime"], errors='coerce', utc=True)
data["Datetime"] = data["Datetime"].dt.tz_convert("UTC")

# %%
data.head()
# Out:
#                    Datetime Resolution code  Total Load  Most recent forecast  \
# 0 2014-12-31 23:00:00+00:00           PT15M    10142.19               9496.05
# 1 2014-12-31 23:15:00+00:00           PT15M    10051.28               9329.17
# 2 2014-12-31 23:30:00+00:00           PT15M     9952.87               9174.72
# 3 2014-12-31 23:45:00+00:00           PT15M     9821.78               9025.46
# 4 2015-01-01 00:00:00+00:00           PT15M     9755.00               9222.33
#
#    Most recent P10  Most recent P90  Day-ahead 6PM forecast  \
# 0          8871.71         10120.38                 9697.59
# 1          8715.80          9942.53                 9526.54
# 2          8571.51          9777.92                 9367.66
# 3          8432.07          9618.85                 9216.09
# 4          8880.23          9564.44                10130.36
#
#    Day-ahead 6PM P10  Day-ahead 6PM P90  Week-ahead forecast
# 0            9076.64           10318.53              9833.37
# 1            8916.55           10136.53              9653.31
# 2            8767.84            9967.47              9473.22
# 3            8625.97            9806.20              9319.45
# 4            9777.87           10482.86              9203.25

# %%
data['Total Load Interpolated'] = data['Total Load'].interpolate(method='linear')

# %%
data["Year"] = [i.year for i in data["Datetime"]]
data["Month"] = [i.month for i in data["Datetime"]]
data["Day"] = [i.day for i in data["Datetime"]]
data["Hour"] = [i.hour for i in data["Datetime"]]
data["Minute"] = [i.minute for i in data["Datetime"]]
data["Season"] = data["Month"]//4

# %% [markdown]
# Lockdown dates:
# - 18/03/2020 -> 04/05/2020
# - 30/10/2020 -> 15/12/2020
# - 20/11/2020 -> 20/01/2022

# %%
data["Lockdown"] = 0

# %%
data.loc[182784:187296, "Lockdown"] = 1
data.loc[204388:208804, "Lockdown"] = 1
data.loc[212260:247300, "Lockdown"] = 1

# %%
data["Difference with previous load"] = [0] + list(np.array(data["Total Load"][1:].to_list()) - np.array(data["Total Load"][:-1].to_list()))
data["Difference with previous load interpolated"] = [0] + list(np.array(data["Total Load Interpolated"][1:].to_list()) - np.array(data["Total Load Interpolated"][:-1].to_list()))

# %%
def get_previous_day_value(df, current_time, column):
    df.set_index("Datetime", inplace=True)  
    previous_day = current_time - pd.DateOffset(hours=1)
    previous_time = previous_day.replace(minute=45)
    if previous_time in df.index:
        return df.loc[previous_time, column]
    return None

data['Total Load Interpolated Persistence'] = data["Datetime"].apply(lambda x: get_previous_day_value(data.copy(), x, 'Total Load Interpolated'))
data['Total Load Persistence'] = data["Datetime"].apply(lambda x: get_previous_day_value(data.copy(), x, 'Total Load'))

# %%
data.head()
# Out:
#                    Datetime Resolution code  Total Load  Most recent forecast  \
# 0 2014-12-31 23:00:00+00:00           PT15M    10142.19               9496.05
# 1 2014-12-31 23:15:00+00:00           PT15M    10051.28               9329.17
# 2 2014-12-31 23:30:00+00:00           PT15M     9952.87               9174.72
# 3 2014-12-31 23:45:00+00:00           PT15M     9821.78               9025.46
# 4 2015-01-01 00:00:00+00:00           PT15M     9755.00               9222.33
#
#    Most recent P10  Most recent P90  Day-ahead 6PM forecast  \
# 0          8871.71         10120.38                 9697.59
# 1          8715.80          9942.53                 9526.54
# 2          8571.51          9777.92                 9367.66
# 3          8432.07          9618.85                 9216.09
# 4          8880.23          9564.44                10130.36
#
#    Day-ahead 6PM P10  Day-ahead 6PM P90  Week-ahead forecast  ...  Month  Day  \
# 0            9076.64           10318.53              9833.37  ...     12   31
# 1            8916.55           10136.53              9653.31  ...     12   31
# 2            8767.84            9967.47              9473.22  ...     12   31
# 3            8625.97            9806.20              9319.45  ...     12   31
# 4            9777.87           10482.86              9203.25  ...      1    1
#
#    Hour  Minute  Season  Lockdown  Difference with previous load  \
# 0    23       0       3         0                           0.00
# 1    23      15       3         0                         -90.91
# 2    23      30       3         0                         -98.41
# 3    23      45       3         0                        -131.09
# 4     0       0       0         0                         -66.78
#
#    Difference with previous load interpolated  \
# 0                                        0.00
# 1                                      -90.91
# 2                                      -98.41
# 3                                     -131.09
# 4                                      -66.78
#
#    Total Load Interpolated Persistence  Total Load Persistence
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
# 3                                  NaN                     NaN
# 4                              9821.78                 9821.78
#
# [5 rows x 22 columns]

# %%
data.tail()
# Out:
#                         Datetime Resolution code  Total Load  \
# 338410 2024-08-26 01:30:00+00:00           PT15M     6709.33
# 338411 2024-08-26 01:45:00+00:00           PT15M     6841.40
# 338412 2024-08-26 02:00:00+00:00           PT15M     6842.97
# 338413 2024-08-26 02:15:00+00:00           PT15M     6905.57
# 338414 2024-08-26 02:30:00+00:00           PT15M     6885.74
#
#         Most recent forecast  Most recent P10  Most recent P90  \
# 338410               6901.54          6734.68          7068.40
# 338411               6880.89          6714.53          7047.25
# 338412               6887.46          6721.35          7053.57
# 338413               6896.76          6730.43          7063.09
# 338414               6910.04          6743.39          7076.69
#
#         Day-ahead 6PM forecast  Day-ahead 6PM P10  Day-ahead 6PM P90  \
# 338410                 6814.75            6556.32            7073.17
# 338411                 6794.36            6536.71            7052.01
# 338412                 6921.37            6664.11            7178.63
# 338413                 6930.71            6673.11            7188.32
# 338414                 6944.06            6685.96            7202.16
#
#         Week-ahead forecast  ...  Month  Day  Hour  Minute  Season  Lockdown  \
# 338410              6860.06  ...      8   26     1      30       2         0
# 338411              6838.49  ...      8   26     1      45       2         0
# 338412              6948.82  ...      8   26     2       0       2         0
# 338413              6937.10  ...      8   26     2      15       2         0
# 338414              6964.77  ...      8   26     2      30       2         0
#
#         Difference with previous load  \
# 338410                         -70.66
# 338411                         132.07
# 338412                           1.57
# 338413                          62.60
# 338414                         -19.83
#
#         Difference with previous load interpolated  \
# 338410                                      -70.66
# 338411                                      132.07
# 338412                                        1.57
# 338413                                       62.60
# 338414                                      -19.83
#
#         Total Load Interpolated Persistence  Total Load Persistence
# 338410                              6859.53                 6859.53
# 338411                              6859.53                 6859.53
# 338412                              6841.40                 6841.40
# 338413                              6841.40                 6841.40
# 338414                              6841.40                 6841.40
#
# [5 rows x 22 columns]

# %%
data.to_csv("Processed_data.csv")
